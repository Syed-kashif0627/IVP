# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Downloading opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting numpy>=1.21.2 (from opencv-python)
#   Downloading numpy-2.2.2-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Downloading opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    - -------------------------------------- 1.0/39.5 MB 5.5 MB/s eta 0:00:07
#    - -------------------------------------- 1.6/39.5 MB 5.0 MB/s eta 0:00:08
#    -- ------------------------------------- 2.6/39.5 MB 4.4 MB/s eta 0:00:09
#    --- ------------------------------------ 3.4/39.5 MB 3.8 MB/s eta 0:00:10
#    ---- ----------------------------------- 4.5/39.5 MB 4.1 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.2/39.5 MB 4.1 MB/s eta 0:00:09
#    ------ --------------------------------- 6.0/39.5 MB 4.0 MB/s eta 0:00:09
#    ------ --------------------------------- 6.8/39.5 MB 4.0 MB/s eta 0:00:09
#    ------- -------------------------------- 7.6/39.5 MB 4.0 MB/s eta 0:00:08
#    -------- ------------------------------- 8.7/39.5 MB 4.0 MB/s eta 0:00:08
#    --------- ------------------------------ 9.4/39.5 MB 4.0 MB/s eta 0:00:08
#    ---------- ----------------------------- 10.2/39.5 MB 4.0 MB/s eta 0:00:08
#    ----------- ---------------------------- 11.0/39.5 MB 4.0 MB/s eta 0:00:08
#    ----------- ---------------------------- 11.8/39.5 MB 4.0 MB/s eta 0:00:07
#    ------------- -------------------------- 12.8/39.5 MB 4.0 MB/s eta 0:00:07
#    ------------- -------------------------- 13.6/39.5 MB 3.9 MB/s eta 0:00:07
#    -------------- ------------------------- 14.4/39.5 MB 3.9 MB/s eta 0:00:07
#    --------------- ------------------------ 15.2/39.5 MB 3.9 MB/s eta 0:00:07
#    ---------------- ----------------------- 16.0/39.5 MB 3.9 MB/s eta 0:00:06
#    ---------------- ----------------------- 16.8/39.5 MB 3.9 MB/s eta 0:00:06
#    ----------------- ---------------------- 17.6/39.5 MB 3.9 MB/s eta 0:00:06
#    ------------------ --------------------- 18.4/39.5 MB 3.9 MB/s eta 0:00:06
#    ------------------- -------------------- 19.4/39.5 MB 3.9 MB/s eta 0:00:06
#    -------------------- ------------------- 20.2/39.5 MB 3.9 MB/s eta 0:00:05
#    --------------------- ------------------ 21.0/39.5 MB 3.9 MB/s eta 0:00:05
#    ---------------------- ----------------- 21.8/39.5 MB 3.9 MB/s eta 0:00:05
#    ---------------------- ----------------- 22.5/39.5 MB 3.9 MB/s eta 0:00:05
#    ----------------------- ---------------- 23.3/39.5 MB 3.9 MB/s eta 0:00:05
#    ------------------------ --------------- 24.4/39.5 MB 3.9 MB/s eta 0:00:04
#    ------------------------- -------------- 25.2/39.5 MB 3.9 MB/s eta 0:00:04
#    -------------------------- ------------- 26.0/39.5 MB 3.9 MB/s eta 0:00:04
#    --------------------------- ------------ 26.7/39.5 MB 3.9 MB/s eta 0:00:04
#    --------------------------- ------------ 27.5/39.5 MB 3.9 MB/s eta 0:00:04
#    ---------------------------- ----------- 28.3/39.5 MB 3.9 MB/s eta 0:00:03
#    ----------------------------- ---------- 29.1/39.5 MB 3.9 MB/s eta 0:00:03
#    ------------------------------ --------- 30.1/39.5 MB 3.9 MB/s eta 0:00:03
#    ------------------------------- -------- 30.9/39.5 MB 3.9 MB/s eta 0:00:03
#    -------------------------------- ------- 31.7/39.5 MB 3.9 MB/s eta 0:00:02
#    -------------------------------- ------- 32.2/39.5 MB 3.9 MB/s eta 0:00:02
#    --------------------------------- ------ 32.8/39.5 MB 3.9 MB/s eta 0:00:02
#    --------------------------------- ------ 33.3/39.5 MB 3.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.8/39.5 MB 3.8 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.6/39.5 MB 3.8 MB/s eta 0:00:02
#    ----------------------------------- ---- 35.4/39.5 MB 3.8 MB/s eta 0:00:02
#    ------------------------------------ --- 36.2/39.5 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------- -- 37.0/39.5 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 37.7/39.5 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  38.5/39.5 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  39.3/39.5 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 39.5/39.5 MB 3.7 MB/s eta 0:00:00
# Downloading numpy-2.2.2-cp313-cp313-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.6 MB 6.0 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.8/12.6 MB 4.7 MB/s eta 0:00:03
#    -------- ------------------------------- 2.6/12.6 MB 4.4 MB/s eta 0:00:03
#    ---------- ----------------------------- 3.4/12.6 MB 4.2 MB/s eta 0:00:03
#    -------------- ------------------------- 4.5/12.6 MB 4.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.2/12.6 MB 4.1 MB/s eta 0:00:02
#    ------------------- -------------------- 6.0/12.6 MB 4.1 MB/s eta 0:00:02
#    --------------------- ------------------ 6.8/12.6 MB 4.1 MB/s eta 0:00:02
#    ------------------------ --------------- 7.6/12.6 MB 4.0 MB/s eta 0:00:02
#    -------------------------- ------------- 8.4/12.6 MB 4.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.2/12.6 MB 4.0 MB/s eta 0:00:01
#    ------------------------------- -------- 10.0/12.6 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.0/12.6 MB 4.0 MB/s eta 0:00:01
#    ------------------------------------- -- 11.8/12.6 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.6 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 3.9 MB/s eta 0:00:00
# Installing collected packages: numpy, opencv-python
# Successfully installed numpy-2.2.2 opencv-python-4.11.0.86

# %%
import cv2

# Load the video
cap = cv2.VideoCapture('sampleVideo.mp4')

# Define the codec and create VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('denoised_video.avi', fourcc, 20.0, (int(cap.get(3)), int(cap.get(4))))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    
    # Apply Gaussian Blur for denoising
    denoised_frame = cv2.GaussianBlur(frame, (5, 5), 0)
    
    # Write the denoised frame
    out.write(denoised_frame)
    
    # Display the frame
    cv2.imshow('Denoised Video', denoised_frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release everything when the job is finished
cap.release()
out.release()
cv2.destroyAllWindows()

# %%
import cv2

# Load the video
cap = cv2.VideoCapture('sampleVideo.mp4')

# Define the codec and create VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'MJPG')
out = cv2.VideoWriter('denoised_video.avi', fourcc, 20.0, (int(cap.get(3)), int(cap.get(4))))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    
    # Apply Gaussian Blur for denoising
    denoised_frame = cv2.GaussianBlur(frame, (5, 5), 0)
    
    # Write the denoised frame
    out.write(denoised_frame)
    
    # Display the frame
    cv2.imshow('Denoised Video', denoised_frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release everything when the job is finished
cap.release()
out.release()
cv2.destroyAllWindows()
